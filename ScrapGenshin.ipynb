# %%
twitter_auth_token = 'bef4f51be49d4511280d0016b3ef78d271c80571'

# %%
# Import required Python package
# !pandas

# Install Node.js (because tweet-harvest built using Node.js)
# !sudo apt-get update
# !sudo apt-get install -y ca-certificates curl gnupg
# !sudo mkdir -p /etc/apt/keyrings
# !curl -fsSL https://deb.nodesource.com/gpgkey/nodesource-repo.gpg.key | sudo gpg --dearmor -o /etc/apt/keyrings/nodesource.gpg

# !NODE_MAJOR=20 && echo "deb [signed-by=/etc/apt/keyrings/nodesource.gpg] https://deb.nodesource.com/node_$NODE_MAJOR.x nodistro main" | sudo tee /etc/apt/sources.list.d/nodesource.list

# !sudo apt-get update
# !sudo apt-get install nodejs -y

# !node -v
# Out:
# /bin/bash: line 1: pandas: command not found
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Ign:4 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Hit:6 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:7 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
# Crawl Data

filename = 'genshin.csv'
search_keyword = 'genshin since:2023-04-01 until:2024-10-01 lang:id'
limit = 150

# !npx -y tweet-harvest@2.6.1 -o "{filename}" -s "{search_keyword}" --tab "LATEST" -l {limit} --token {twitter_auth_token}
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧npm warn deprecated rimraf@3.0.2: Rimraf versions prior to v4 are no longer supported
# ⠧npm warn deprecated inflight@1.0.6: This module is not supported, and leaks memory. Do not use it. Check out lru-cache if you want a good and tested way to coalesce async requests by a key value, which is much more comprehensive and powerful.
# ⠇npm warn deprecated glob@7.2.3: Glob versions prior to v9 are no longer supported
# ⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼⠴Tweet Harvest [v2.6.1]
#
# Research by Helmi Satria
# Use it for Educational Purposes only!
#
# This script uses Chromium Browser to crawl data from Twitter with your Twitter auth token.
# Please enter your Twitter auth token when prompted.
#
# ...

# %%
import pandas as pd

# Specify the path to your CSV file
file_path = f"tweets-data/{filename}"

# Read the CSV file into a pandas DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Display the DataFrame
display(df['full_text'])
# Out:
# 0      Genshin Impact Versi 5.1 Akan Hadir 9 Oktober ...
# 1      Hiii weekend ini yg mau ke Kira Kira Art Marke...
# 2                                 D-41 jadi kesini ga ya
# 3      Nggak diingetin meow meow sama cowokku (2 hari...
# 4      @paimonfess Aku well build sign tapi C0 nder m...
#                              ...
# 98         lucuan bikin apa kira2 buat pet baru genshin
# 99     @dainservice tadi pun di ingame masih banyak y...
# 100    yay xiaru!! #Xiao #Genshin #selfship https://t...
# 101          Login genshin tar ae lah sekalian claim kue
# 102                 daripada galau mending mari kita DU
# Name: full_text, Length: 103, dtype: object

# %%
# utilities
import re
import pandas as pd

# nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import nltk

from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
df = pd.read_csv('/content/tweets-data/genshin.csv')
df.head()
# Out:
#    conversation_id_str                      created_at  favorite_count  \
# 0  1840904401948737721  Mon Sep 30 23:59:46 +0000 2024               1
# 1  1840904015842066922  Mon Sep 30 23:58:14 +0000 2024               0
# 2  1837700382656811518  Mon Sep 30 23:53:20 +0000 2024               0
# 3  1840902532329324909  Mon Sep 30 23:52:20 +0000 2024               0
# 4  1840898200003088542  Mon Sep 30 23:50:51 +0000 2024               0
#
#                                            full_text               id_str  \
# 0  Genshin Impact Versi 5.1 Akan Hadir 9 Oktober ...  1840904401948737721
# 1  Hiii weekend ini yg mau ke Kira Kira Art Marke...  1840904015842066922
# 2                             D-41 jadi kesini ga ya  1840902781953327296
# 3  Nggak diingetin meow meow sama cowokku (2 hari...  1840902532329324909
# 4  @paimonfess Aku well build sign tapi C0 nder m...  1840902158952382701
#
#   image_url in_reply_to_screen_name lang   location  quote_count  reply_count  \
# ...

# %%
emojis = {':)': 'smile', ':-)': 'smile', ';d': 'wink', ':-E': 'vampire', ':(': 'sad',
          ':-(': 'sad', ':-<': 'sad', ':P': 'raspberry', ':O': 'surprised',
          ':-@': 'shocked', ':@': 'shocked',':-$': 'confused', ':\\': 'annoyed',
          ':#': 'mute', ':X': 'mute', ':^)': 'smile', ':-&': 'confused', '$_$': 'greedy',
          '@@': 'eyeroll', ':-!': 'confused', ':-D': 'smile', ':-0': 'yell', 'O.o': 'confused',
          '<(-_-)>': 'robot', 'd[-_-]b': 'dj', ":'-)": 'sadsmile', ';)': 'wink',
          ';-)': 'wink', 'O:-)': 'angel','O*-)': 'angel','(:-D': 'gossip', '=^.^=': 'cat'}

# %%
def preprocess(textdata, stopwords_id, emojis):
    processedText = []

    wordLemm = WordNetLemmatizer()

    urlPattern = r"((http://)[^ ]*|(https://)[^ ]*|( www\.)[^ ]*)"
    userPattern = '@[^\s]+'
    alphaPattern = "[^a-zA-Z0-9]"
    sequencePattern = r"(.)\1\1+"
    seqReplacePattern = r"\1\1"

    for tweet in textdata:
        tweet = tweet.lower()

        tweet = re.sub(urlPattern, ' ', tweet)
        for emoji in emojis.keys():
            tweet = tweet.replace(emoji, "" + emojis[emoji])
        tweet = re.sub(userPattern, '', tweet)
        tweet = re.sub(alphaPattern, " ", tweet)
        tweet = re.sub(sequencePattern, seqReplacePattern, tweet)

        tweetwords = ''
        for word in tweet.split():
            if word not in stopwords_id:
                if len(word) > 1:
                    word = wordLemm.lemmatize(word)
                    tweetwords += (word + ' ')

        processedText.append(tweetwords)

    return processedText

def tokenizingText(
    text,
):  # Tokenizing or splitting a string, text into a list of tokens
    text = word_tokenize(text)
    return text


def filteringText(text):  # Remove stopwors in a text
    listStopwords = set(stopwords.words("indonesian"))
    filtered = []
    for txt in text:
        if txt not in listStopwords:
            filtered.append(txt)
    text = filtered
    return text


def toSentence(list_words):  # Convert list of words into sentence
    sentence = " ".join(word for word in list_words)
    return sentence

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')

nltk_stw_id = stopwords.words('indonesian')

# # Preprocessing df data

df['text_clean'] = preprocess(df['full_text'], nltk_stw_id, emojis)

df["text_preprocessed"] = df["text_clean"].apply(tokenizingText)
df["text_preprocessed"] = df["text_preprocessed"].apply(filteringText)

df.to_csv('genshin.old.csv', index = False, header = True,index_label=None)

df.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
#    conversation_id_str                      created_at  favorite_count  \
# 0  1840904401948737721  Mon Sep 30 23:59:46 +0000 2024               1
# 1  1840904015842066922  Mon Sep 30 23:58:14 +0000 2024               0
# 2  1837700382656811518  Mon Sep 30 23:53:20 +0000 2024               0
# 3  1840902532329324909  Mon Sep 30 23:52:20 +0000 2024               0
# 4  1840898200003088542  Mon Sep 30 23:50:51 +0000 2024               0
#
#                                            full_text               id_str  \
# 0  Genshin Impact Versi 5.1 Akan Hadir 9 Oktober ...  1840904401948737721
# ...

# %%
date = [ x[4:19] for x in df['created_at']]
df['created_at'] = date
df['created_at']
# Out:
# 0      Sep 30 23:59:46
# 1      Sep 30 23:58:14
# 2      Sep 30 23:53:20
# 3      Sep 30 23:52:20
# 4      Sep 30 23:50:51
#             ...
# 98     Sep 30 16:55:40
# 99     Sep 30 16:54:08
# 100    Sep 30 16:51:44
# 101    Sep 30 16:51:20
# 102    Sep 30 16:50:23
# Name: created_at, Length: 103, dtype: object

# %%
df = df[['created_at','text_clean','text_preprocessed']]
df
# Out:
#           created_at                                         text_clean  \
# 0    Sep 30 23:59:46           genshin impact versi hadir oktober 2024
# 1    Sep 30 23:58:14  hii weekend yg art market mampir table 41 ya f...
# 2    Sep 30 23:53:20                                   41 kesini ga ya
# 3    Sep 30 23:52:20         nggak diingetin meow meow cowokku gak isi
# 4    Sep 30 23:50:51  well build sign c0 nder kah gomen egk con nung...
# ..               ...                                                ...
# 98   Sep 30 16:55:40                    lucuan bikin kira2 pet genshin
# 99   Sep 30 16:54:08                         ingame gak acc ueueueueue
# 100  Sep 30 16:51:44                   yay xiaru xiao genshin selfship
# 101  Sep 30 16:51:20                    login genshin tar ae claim kue
# 102  Sep 30 16:50:23                             galau mending mari du
#
#                                      text_preprocessed
# 0       [genshin, impact, versi, hadir, oktober, 2024]
# ...

# %%
df.to_csv('genshin.csv', index = False, header = True,index_label=None)
